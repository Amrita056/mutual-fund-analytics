# %% [markdown]
# # Mutual Fund Exploratory Data Analysis (EDA)
#
# ## Capstone Project – Mutual Fund Analytics
#
# ### Objective
# Perform Exploratory Data Analysis on Mutual Fund datasets to understand NAV trends, AUM growth, SIP inflows, investor demographics, portfolio allocation, and benchmark performance.

# %% [markdown]
# # Mutual Fund Analytics - Exploratory Data Analysis (EDA)
#
# ## Capstone Project I
#
# ### Student
# **Amrita Pathak**
#
# ### Objective
#
# This project performs Exploratory Data Analysis (EDA) on Mutual Fund datasets using Python.
#
# The analysis focuses on:
#
# - NAV Trend
# - AUM Growth
# - SIP Inflows
# - Category Inflows
# - Investor Demographics
# - Geographic Distribution
# - Folio Growth
# - Benchmark Analysis
# - Correlation Analysis
# - Portfolio Sector Allocation
#
# The project uses:
#
# - Pandas
# - Matplotlib
# - Seaborn
# - Plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

print("Libraries Loaded Successfully")
# Out:
# Libraries Loaded Successfully

# %%
print("EDA Notebook Ready")
# Out:
# EDA Notebook Ready

# %% [markdown]
# # Dataset Used
#
# The project contains the following datasets:
#
# - 01_fund_master.csv
# - 02_nav_history.csv
# - 03_aum_by_fund_house.csv
# - 04_monthly_sip_inflows.csv
# - 05_category_inflows.csv
# - 06_industry_folio_count.csv
# - 07_scheme_performance.csv
# - 08_investor_transactions.csv
# - 09_portfolio_holdings.csv
# - 10_benchmark_indices.csv

# %% [markdown]
# # EDA Findings
#
# ## Finding 1
# The NIFTY50 benchmark reached its highest closing value in March 2024 and its lowest value in January 2022.
#
# ## Finding 2
# SBI Mutual Fund has the highest Assets Under Management (AUM) among all fund houses.
#
# ## Finding 3
# Monthly SIP inflows steadily increased over time, reaching their highest level in December 2025.
#
# ## Finding 4
# The majority of investors belong to the 26–35 age group.
#
# ## Finding 5
# Male investors account for approximately two-thirds of the investor base.
#
# ## Finding 6
# T30 cities contribute around 66% of investments, while B30 cities contribute around 34%.
#
# ## Finding 7
# Punjab and Tamil Nadu have the highest investment amounts among the listed states.
#
# ## Finding 8
# Banking is the largest portfolio sector allocation, followed by IT and Pharma.
#
# ## Finding 9
# Most mutual fund schemes show weak correlation with one another based on daily returns.
#
# ## Finding 10
# Overall mutual fund participation and investment trends indicate steady market growth over the analysis period.

# %% [markdown]
# # Key EDA Findings
#
# ### Finding 1
# NIFTY50 reached its highest closing value in March 2024.
#
# ### Finding 2
# SBI Mutual Fund has the highest Assets Under Management.
#
# ### Finding 3
# Monthly SIP inflows steadily increased and reached their peak in December 2025.
#
# ### Finding 4
# The 26–35 age group has the highest number of investors.
#
# ### Finding 5
# Male investors account for nearly two-thirds of the investor base.
#
# ### Finding 6
# T30 cities contribute approximately 66% of total investments.
#
# ### Finding 7
# Punjab and Tamil Nadu show the highest investment amounts.
#
# ### Finding 8
# Banking has the highest portfolio allocation.
#
# ### Finding 9
# Most selected mutual fund schemes show weak correlation.
#
# ### Finding 10
# Overall investor participation increased consistently throughout the study period.

# %% [markdown]
# # Chart 1
#
# ## NAV Trend Analysis

# %%
from IPython.display import Image

Image("nav_trend.png")

# %% [markdown]
# # Conclusion
#
# The exploratory data analysis reveals strong growth in the Indian mutual fund industry during the analysis period.
#
# Key observations include:
#
# - SBI Mutual Fund dominates the market.
# - SIP investments continue to increase.
# - Young investors (26–35 years) contribute the largest share.
# - Banking and IT remain the major investment sectors.
# - T30 cities account for the majority of investments.
# - Mutual fund participation has consistently increased, indicating positive investor confidence.
#
# Overall, the project successfully analyzes mutual fund performance, investor behaviour, portfolio allocation, and market trends using Python-based data visualization techniques.
